# %% [markdown]
# ## Import All Required Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read The Dataset

# %%
song = pd.read_csv(r'C:\Users\shekh\OneDrive\Desktop\SongRecommendationSystem\notebooks\data\bosong.csv')
song.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %% [markdown]
# ## Check Null Value In Out dataset

# %%
song.isnull().sum()
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
song.dropna(inplace=True)

# %%
song.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %% [markdown]
# ## Check Duplicates values in Our Dataset

# %%
song.duplicated(subset='Song-Name').sum()
# Out:
# 80

# %%
song = song.drop_duplicates(subset="Song-Name").reset_index()

# %%
song.duplicated(subset='Song-Name').sum()
# Out:
# 0

# %% [markdown]
# #### Handle Duplicates Songs By removing All duplicates songs

# %% [markdown]
# ## Shape Of the Dataset

# %%
song.shape
# Out:
# (2327, 6)

# %% [markdown]
# ## Read Top 5 Data

# %%
song.head()
# Out:
#    index         Song-Name                                    Singer/Artists  \
# 0      0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1      1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2      2  Apna Time Aayega                                     Ranveer Singh
# 3      3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4      4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %% [markdown]
# ## Filter Rating Column

# %%
song['User-Rating']
# Out:
# 0       8.8/10
# 1       9.0/10
# 2       9.7/10
# 3       9.1/10
# 4       9.2/10
#          ...
# 2322    6.2/10
# 2323    7.2/10
# 2324    7.5/10
# 2325    6.5/10
# 2326    6.6/10
# Name: User-Rating, Length: 2327, dtype: object

# %%
rating = []

for i in song['User-Rating']:
    rating.append(i[:3])

# %%
rating
# Out:
# ['8.8',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.2',
#  '9.1',
#  '9.2',
#  '9.5',
#  '9.2',
#  '9.6',
#  '8.8',
#  '8.4',
#  '9.1',
#  '9.2',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '9.2',
#  '9.2',
#  '9.5',
#  '8.6',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.2',
#  '9.5',
#  '9.4',
#  '8.7',
#  '9.3',
#  '9.3',
#  '9.5',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '8.4',
#  '8.4',
#  '8.8',
#  '9.2',
#  '9.2',
#  '9.6',
#  '9.6',
#  '9.0',
#  '9.1',
#  '8.5',
#  '9.5',
#  '8.5',
#  '9.7',
#  '8.9',
#  '9.6',
#  '8.5',
#  '9.1',
#  '8.7',
#  '8.6',
#  '9.3',
#  '9.7',
#  '8.9',
#  '9.0',
#  '9.0',
#  '9.3',
#  '9.3',
#  '9.1',
#  '9.0',
#  '9.7',
#  '9.2',
#  '9.1',
#  '9.0',
#  '8.9',
#  '9.5',
#  '9.5',
#  '9.7',
#  '9.0',
#  '8.1',
#  '8.1',
#  '9.5',
#  '8.6',
#  '9.4',
#  '9.0',
#  '9.0',
#  '9.6',
#  '9.3',
#  '9.0',
#  '9.2',
#  '9.3',
#  '9.1',
#  '8.6',
#  '9.5',
#  '9.5',
#  '9.0',
#  '9.4',
#  '9.2',
#  '9.6',
#  '9.3',
#  '7.7',
#  '9.2',
#  '9.3',
#  '7.7',
# ...

# %%
song['User-Rating'] = rating

# %%
song.head()
# Out:
#    index         Song-Name                                    Singer/Artists  \
# 0      0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1      1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2      2  Apna Time Aayega                                     Ranveer Singh
# 3      3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4      4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba         8.8
# 1  BollywoodDanceRomantic    Luka Chuppi         9.0
# 2          BollywoodDance      Gully Boy         9.7
# 3          BollywoodDance  Total Dhamaal         9.1
# 4       BollywoodRomantic         Simmba         9.2

# %% [markdown]
# ## Read Bottom 5 dataset

# %%
song.tail(5)
# Out:
#       index                           Song-Name  \
# 2322   2415              Jana Tumhare Pyar Mein
# 2323   2416             Tum Jaise Bigde Babu Se
# 2324   2417              O Yaad Nahi Bhool Gaya
# 2325   2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2326   2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                       Singer/Artists           Genre  \
# 2322                          Mukesh  BollywoodDance
# 2323                 Lata Mangeshkar  BollywoodDance
# 2324  Lata Mangeshkar, Suresh Wadkar  BollywoodDance
# 2325                     Jagjit Kaur  BollywoodDance
# 2326                     Asha Bhosle  BollywoodDance
#
#                     Album/Movie User-Rating
# 2322                    Sasural         6.2
# 2323  Jab Pyar Kisi Se Hota Hai         7.2
# 2324                      Lamhe         7.5
# 2325          Shola Aur Shabnam         6.5
# 2326          Shola Aur Shabnam         6.6

# %% [markdown]
# #### Apply string operating in singer and album column remove white space between the word because better understanding name and album to the machine learning model and given best accuracy purpose

# %%
song['Album/Movie'] = song['Album/Movie'].str.replace(" ","")

# %%
song.head()
# Out:
#    index         Song-Name                                    Singer/Artists  \
# 0      0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1      1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2      2  Apna Time Aayega                                     Ranveer Singh
# 3      3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4      4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre   Album/Movie User-Rating
# 0          BollywoodDance        Simmba         8.8
# 1  BollywoodDanceRomantic    LukaChuppi         9.0
# 2          BollywoodDance      GullyBoy         9.7
# 3          BollywoodDance  TotalDhamaal         9.1
# 4       BollywoodRomantic        Simmba         9.2

# %% [markdown]
# ### Replace , in Singer Column by " " white space because of data filtering purpose and seperate singer name

# %%
song['Singer/Artists'] = song['Singer/Artists'].str.replace(","," ")

# %%
song.head()
# Out:
#    index         Song-Name                                    Singer/Artists  \
# 0      0       Aankh Marey               Kumar Sanu  Mika Singh  Neha Kakkar
# 1      1         Coca Cola                          Neha Kakkar  Tony Kakkar
# 2      2  Apna Time Aayega                                     Ranveer Singh
# 3      3            Mungda             Jyotica Tangri  Shaan  Subhro Ganguly
# 4      4          Tere Bin  Asees Kaur  Rahat Fateh Ali Khan  Tanishk Bagchi
#
#                     Genre   Album/Movie User-Rating
# 0          BollywoodDance        Simmba         8.8
# 1  BollywoodDanceRomantic    LukaChuppi         9.0
# 2          BollywoodDance      GullyBoy         9.7
# 3          BollywoodDance  TotalDhamaal         9.1
# 4       BollywoodRomantic        Simmba         9.2

# %% [markdown]
# ### Create New Column tags for recommendation purpose (Develop Content Base Recommendation System)

# %%
song['tags'] = song['Singer/Artists'] + " " + song['Genre'] + " " + song['Album/Movie'] + " " + song['User-Rating']

# %%
song
# Out:
#       index                           Song-Name  \
# 0         0                         Aankh Marey
# 1         1                           Coca Cola
# 2         2                    Apna Time Aayega
# 3         3                              Mungda
# 4         4                            Tere Bin
# ...     ...                                 ...
# 2322   2415              Jana Tumhare Pyar Mein
# 2323   2416             Tum Jaise Bigde Babu Se
# 2324   2417              O Yaad Nahi Bhool Gaya
# 2325   2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2326   2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu  Mika Singh  Neha Kakkar
# 1                             Neha Kakkar  Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri  Shaan  Subhro Ganguly
# 4     Asees Kaur  Rahat Fateh Ali Khan  Tanishk Bagchi
# ...

# %%
new_data = song[['Song-Name',"tags",'Singer/Artists']]
new_data.rename(columns={'Singer/Artists':"artists"},inplace=True)
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_20408\4061981907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.rename(columns={'Singer/Artists':"artists"},inplace=True)

# %%
new_data.head()
# Out:
#           Song-Name                                               tags  \
# 0       Aankh Marey  Kumar Sanu  Mika Singh  Neha Kakkar BollywoodD...
# 1         Coca Cola  Neha Kakkar  Tony Kakkar BollywoodDanceRomanti...
# 2  Apna Time Aayega          Ranveer Singh BollywoodDance GullyBoy 9.7
# 3            Mungda  Jyotica Tangri  Shaan  Subhro Ganguly Bollywoo...
# 4          Tere Bin  Asees Kaur  Rahat Fateh Ali Khan  Tanishk Bagc...
#
#                                             artists
# 0               Kumar Sanu  Mika Singh  Neha Kakkar
# 1                          Neha Kakkar  Tony Kakkar
# 2                                     Ranveer Singh
# 3             Jyotica Tangri  Shaan  Subhro Ganguly
# 4  Asees Kaur  Rahat Fateh Ali Khan  Tanishk Bagchi

# %% [markdown]
# ## Convert tags data into lower case

# %%
new_data['tags'] = new_data['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_20408\2492974546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['tags'] = new_data['tags'].apply(lambda x:x.lower())

# %%
new_data.head()
# Out:
#           Song-Name                                               tags  \
# 0       Aankh Marey  kumar sanu  mika singh  neha kakkar bollywoodd...
# 1         Coca Cola  neha kakkar  tony kakkar bollywooddanceromanti...
# 2  Apna Time Aayega          ranveer singh bollywooddance gullyboy 9.7
# 3            Mungda  jyotica tangri  shaan  subhro ganguly bollywoo...
# 4          Tere Bin  asees kaur  rahat fateh ali khan  tanishk bagc...
#
#                                             artists
# 0               Kumar Sanu  Mika Singh  Neha Kakkar
# 1                          Neha Kakkar  Tony Kakkar
# 2                                     Ranveer Singh
# 3             Jyotica Tangri  Shaan  Subhro Ganguly
# 4  Asees Kaur  Rahat Fateh Ali Khan  Tanishk Bagchi

# %% [markdown]
# ### Convert Tags column into vector and find relationship between songs for recommendation

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=20000)

# %%
vectors=cv.fit_transform(new_data['tags']).toarray()

# %%
vectors.shape
# Out:
# (2327, 1884)

# %%
cv.get_feature_names_out()
# Out:
# array(['13', '1920', '1921', ..., 'zindaginamilegidobara',
#        'zindagiyehzindagi', 'zubeen'], dtype=object)

# %% [markdown]
# ### Find relationship between songs usng tags column by using cosine_similarity distance

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %%
sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])
# Out:
# [(0, 0.9999999999999998),
#  (135, 0.5773502691896258),
#  (5, 0.5303300858899106),
#  (34, 0.5303300858899106),
#  (182, 0.5303300858899106),
#  (266, 0.5303300858899106),
#  (366, 0.5303300858899106),
#  (457, 0.5303300858899106),
#  (532, 0.5303300858899106),
#  (578, 0.5303300858899106),
#  (596, 0.5303300858899106),
#  (805, 0.5303300858899106),
#  (903, 0.5303300858899106),
#  (1352, 0.5303300858899106),
#  (1556, 0.5303300858899106),
#  (1879, 0.5303300858899106),
#  (2089, 0.5303300858899106),
#  (2212, 0.5303300858899106),
#  (2295, 0.5303300858899106),
#  (54, 0.4999999999999999),
#  (645, 0.4999999999999999),
#  (1822, 0.4999999999999999),
#  (1775, 0.49029033784546006),
#  (358, 0.47434164902525683),
#  (706, 0.47434164902525683),
#  (2069, 0.4714045207910316),
#  (299, 0.4472135954999579),
#  (306, 0.4472135954999579),
#  (394, 0.4472135954999579),
#  (1826, 0.4472135954999579),
#  (179, 0.44194173824159216),
#  (11, 0.4330127018922194),
#  (19, 0.4330127018922194),
# ...

# %%
new_data.rename(columns={'Song-Name':"title"},inplace=True)
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_20408\225660933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.rename(columns={'Song-Name':"title"},inplace=True)

# %%
new_data
# Out:
#                                    title  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2322              Jana Tumhare Pyar Mein
# 2323             Tum Jaise Bigde Babu Se
# 2324              O Yaad Nahi Bhool Gaya
# 2325   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2326  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags  \
# 0     kumar sanu  mika singh  neha kakkar bollywoodd...
# 1     neha kakkar  tony kakkar bollywooddanceromanti...
# 2             ranveer singh bollywooddance gullyboy 9.7
# 3     jyotica tangri  shaan  subhro ganguly bollywoo...
# 4     asees kaur  rahat fateh ali khan  tanishk bagc...
# ...                                                 ...
# 2322                  mukesh bollywooddance sasural 6.2
# ...

# %% [markdown]
# ### Create Recommendation function to recommend purpose

# %%
def recommend(music):
    music_index = new_data[new_data['title']==music].index[0]
    distance = similarity[music_index]
    music_list = sorted(list(enumerate(distance)),reverse=True,key=lambda x:x[1])[1:11]

    for i in music_list:
        print(new_data.iloc[i[0]].title)

# %%
recommend("Coca Cola")
# Out:
# Mile Ho Tum (Reprise)
# Sawan Aaya Hai (Unplugged Version)
# Mohabbat Nasha Hai
# Helicopter
# Dil Ashkon Mein
# La La La (Baazaar)
# London Thumakda
# Gali Gali
# Do Peg Maar
# O Janiya

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the TfidfVectorizer
tfidf = TfidfVectorizer(max_features=20000)

# Fit and transform the data
vectors1 = tfidf.fit_transform(new_data['tags']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity1=cosine_similarity(vectors1)

# %%
sorted(list(enumerate(similarity1[0])),reverse=True,key=lambda x:x[1])
# Out:
# [(0, 1.0),
#  (135, 0.3673627979707203),
#  (903, 0.3583843898735741),
#  (645, 0.35306462122128324),
#  (266, 0.35250030661932247),
#  (273, 0.342517695497446),
#  (25, 0.3392434403265707),
#  (5, 0.3349481528170323),
#  (241, 0.32813946094047053),
#  (54, 0.3247425361315097),
#  (1, 0.32315095705262115),
#  (358, 0.3206817135843276),
#  (457, 0.3187925072458354),
#  (596, 0.3187925072458354),
#  (805, 0.3187925072458354),
#  (2089, 0.3187925072458354),
#  (182, 0.3083401894065196),
#  (578, 0.3083401894065196),
#  (394, 0.30715134577191183),
#  (366, 0.30377767916113463),
#  (532, 0.30377767916113463),
#  (1556, 0.30377767916113463),
#  (2212, 0.30377767916113463),
#  (34, 0.2983111437339246),
#  (40, 0.2973492337882615),
#  (87, 0.2925252430094283),
#  (339, 0.28677928140292686),
#  (1144, 0.28480596552515347),
#  (1826, 0.2825755176511969),
#  (1879, 0.28215645513479803),
#  (299, 0.27971259705832185),
#  (116, 0.27729511302808774),
#  (1775, 0.27595407642141),
# ...

# %%
def recommend1(music):
    music_index = new_data[new_data['title']==music].index[0]
    distance = similarity1[music_index]
    music_list = sorted(list(enumerate(distance)),reverse=True,key=lambda x:x[1])[1:11]

    for i in music_list:
        print(new_data.iloc[i[0]].title)

# %%
recommend1("Coca Cola")
# Out:
# Mohabbat Nasha Hai
# Mile Ho Tum (Reprise)
# Helicopter
# Sawan Aaya Hai (Unplugged Version)
# Dil Ashkon Mein
# O Janiya
# Do Peg Maar
# London Thumakda
# Gali Gali
# Akkad Bakkad

# %% [markdown]
# ### Check 2 algo for vectorization countVectorization and tfidf algo but better recommendation given by countVectorization algo so that i am select countVectorization algo for recommendation purpose

# %%
recommend("Aankh Marey")
# Out:
# Hawa Hawa
# Gali Gali
# Milegi Milegi
# Sexy Baliye
# Do Peg Maar
# Mind Blowing
# Aaj Ki Party
# The Padman Song
# Mauja Hi Mauja
# 440 Volt

# %%
new_data
# Out:
#                                    title  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2322              Jana Tumhare Pyar Mein
# 2323             Tum Jaise Bigde Babu Se
# 2324              O Yaad Nahi Bhool Gaya
# 2325   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2326  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags  \
# 0     kumar sanu  mika singh  neha kakkar bollywoodd...
# 1     neha kakkar  tony kakkar bollywooddanceromanti...
# 2             ranveer singh bollywooddance gullyboy 9.7
# 3     jyotica tangri  shaan  subhro ganguly bollywoo...
# 4     asees kaur  rahat fateh ali khan  tanishk bagc...
# ...                                                 ...
# 2322                  mukesh bollywooddance sasural 6.2
# ...

# %%
recommend('Tere Bin')
# Out:
# Sanu Ek Pal Chain
# Jag Ghoomeya
# Nit Khair Manga
# Nazar Se Nazar Mile
# Ishq Risk
# Tera Deedar Hua
# Sufi Salam
# Tum Jo Aaye
# Yeh Jo Halki Halki Khumariya
# Aaj Din Chadheya

# %%
recommend1('Tere Bin')
# Out:
# Jag Ghoomeya
# Yeh Jo Halki Halki Khumariya
# Mere Rashke Qamar
# Tera Deedar Hua
# Dil To Bachcha Hai
# Sanu Ek Pal Chain
# Nit Khair Manga
# Jiya Dhadak Dhadak Jaye
# Ishq Risk
# Sufi Salam

# %% [markdown]
# ### Save pickel file

# %%
import pickle

# %%
pickle.dump(new_data,open(r"C:\Users\shekh\OneDrive\Desktop\SongRecommendationSystem\artifacts\musicrec.pkl","wb"))
pickle.dump(similarity,open(r"C:\Users\shekh\OneDrive\Desktop\SongRecommendationSystem\artifacts\similarity.pkl","wb"))

# %% [markdown]
# ## Name Of the Song

# %%
from box import ConfigBox
import requests
def fetch_poster(music_title):
    response = requests.get("https://saavn.dev/api/search/songs?query={}".format(music_title))
    data = response.json()
    data = ConfigBox(data)
    return data['data'].results[0].name

# %%
fetch_poster("Aankh Marey")
# Out:
# 'Aankh Marey'

# %% [markdown]
# ## Year of the song,type,duration,language,album name

# %%
from box import ConfigBox
import requests
def fetch_poster(music_title):
    response = requests.get("https://saavn.dev/api/search/songs?query={}".format(music_title))
    data = response.json()
    data = ConfigBox(data)
    return data['data'].results[0].year,data['data'].results[0].type,data['data'].results[0].duration,data['data'].results[0].language,data['data'].results[0].album.name,data['data'].results[0].url,data['data'].results[0].label
fetch_poster("Aankh Marey")
# Out:
# ('2018',
#  'song',
#  212,
#  'hindi',
#  'Simmba',
#  'https://www.jiosaavn.com/song/aankh-marey/BiQ9A0N9QXY',
#  'T-Series')

# %%
from box import ConfigBox
import requests
def fetch_poster(music_title):
    response = requests.get("https://saavn.dev/api/search/songs?query={}".format(music_title))
    data = response.json()
    data = ConfigBox(data)
    return data['data'].results[0].artists.primary[0].name,data['data'].results[0].artists.primary[0].role, data['data'].results[0].artists.primary[0].image[1].url
fetch_poster("Aankh Marey")
# Out:
# ('Neha Kakkar',
#  'primary_artists',
#  'https://c.saavncdn.com/artists/Neha_Kakkar_006_20200822042626_150x150.jpg')

# %%
def fetch_poster(music_title):
    response = requests.get("https://saavn.dev/api/search/songs?query={}".format(music_title))
    data = response.json()
    data = ConfigBox(data)
    return data['data'].results[0].url

# %%
fetch_poster("Aankh Marey")
# Out:
# 'https://www.jiosaavn.com/song/aankh-marey/BiQ9A0N9QXY'

# %%
new_data[new_data['title']=="Mile Ho Tum (Reprise)"]['artists'].str.split(' ')
# Out:
# 25    [Neha, Kakkar, , Tony, Kakkar]
# Name: artists, dtype: object

# %%
data = pd.read_csv(r'C:\Users\shekh\OneDrive\Desktop\SongRecommendationSystem\notebooks\data\spotify_millsongdata.csv')

# %%
data =data.sample(5000).drop('link', axis=1).reset_index(drop=True)

# %%
data.head(20)
# Out:
#                     artist                                   song  \
# 0              The Beatles                             For No One
# 1          David Allan Coe             Now I Lay Me Down To Cheat
# 2            Kylie Minogue                             In My Arms
# 3            Willie Nelson                     Good Hearted Woman
# 4   Nitty Gritty Dirt Band                         Oh What A Love
# 5               Tim McGraw                      Just Be Your Tear
# 6                      XTC               All Along The Watchtower
# 7     Beauty And The Beast                    If I Can't Love Her
# 8               Tim McGraw                           Sing Me Home
# 9                    Kinks                           Lazy Old Sun
# 10       Weird Al Yankovic                          Good Old Days
# 11            Kenny Rogers  In The Wee Small Hours Of The Morning
# 12                  Utopia                Everybody Else Is Wrong
# ...

# %%
music_dict = pickle.load(open(r'C:\Users\shekh\OneDrive\Desktop\SongRecommendationSystem\artifacts\musicrec.pkl', 'rb'))
music = pd.DataFrame(music_dict)

similarity = pickle.load(open(r'C:\Users\shekh\OneDrive\Desktop\SongRecommendationSystem\artifacts\similarity.pkl', 'rb'))

# %%
music
# Out:
#                                    title  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2322              Jana Tumhare Pyar Mein
# 2323             Tum Jaise Bigde Babu Se
# 2324              O Yaad Nahi Bhool Gaya
# 2325   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2326  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags  \
# 0     kumar sanu  mika singh  neha kakkar bollywoodd...
# 1     neha kakkar  tony kakkar bollywooddanceromanti...
# 2             ranveer singh bollywooddance gullyboy 9.7
# 3     jyotica tangri  shaan  subhro ganguly bollywoo...
# 4     asees kaur  rahat fateh ali khan  tanishk bagc...
# ...                                                 ...
# 2322                  mukesh bollywooddance sasural 6.2
# ...

# %%
distances = sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x: x[1])

# %%
distances
# Out:
# [(0, 0.9999999999999998),
#  (135, 0.5773502691896258),
#  (5, 0.5303300858899106),
#  (34, 0.5303300858899106),
#  (182, 0.5303300858899106),
#  (266, 0.5303300858899106),
#  (366, 0.5303300858899106),
#  (457, 0.5303300858899106),
#  (532, 0.5303300858899106),
#  (578, 0.5303300858899106),
#  (596, 0.5303300858899106),
#  (805, 0.5303300858899106),
#  (903, 0.5303300858899106),
#  (1352, 0.5303300858899106),
#  (1556, 0.5303300858899106),
#  (1879, 0.5303300858899106),
#  (2089, 0.5303300858899106),
#  (2212, 0.5303300858899106),
#  (2295, 0.5303300858899106),
#  (54, 0.4999999999999999),
#  (645, 0.4999999999999999),
#  (1822, 0.4999999999999999),
#  (1775, 0.49029033784546006),
#  (358, 0.47434164902525683),
#  (706, 0.47434164902525683),
#  (2069, 0.4714045207910316),
#  (299, 0.4472135954999579),
#  (306, 0.4472135954999579),
#  (394, 0.4472135954999579),
#  (1826, 0.4472135954999579),
#  (179, 0.44194173824159216),
#  (11, 0.4330127018922194),
#  (19, 0.4330127018922194),
# ...

# %%
for i in distances[1:20]:
        # fetch the movie poster
        artist = music.iloc[i[0]].artists
        print("artist name ",artist)
# Out:
# artist name  Mika Singh  Prakriti Kakkar
# artist name  Neha Kakkar
# artist name  Mika Singh
# artist name  Mika Singh
# artist name  Neha Kakkar
# artist name  Mika Singh
# artist name  Mika Singh
# artist name  Mika Singh
# artist name  Mika Singh
# artist name  Mika Singh
# artist name  Mika Singh
# artist name  Neha Kakkar
# artist name  Kumar Sanu
# artist name  Mika Singh
# artist name  Mika Singh
# artist name  Mika Singh
# artist name  Mika Singh
# artist name  Kumar Sanu
# artist name  Arijit Singh  Meet Bros  Neha Kakkar

# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

CLIENT_ID = "70a9fb89662f4dac8d07321b259eaad7"
CLIENT_SECRET = "4d6710460d764fbbb8d8753dc094d131"

# Initialize the Spotify client
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_song_album_cover_url(song_name, artist_name):
    search_query = f"track:{song_name} artist:{artist_name}"
    results = sp.search(q=search_query, type="track")

    if results and results["tracks"]["items"]:
        track = results["tracks"]["items"][0]
        album_cover_url = track["album"]["images"][0]["url"]
        print(album_cover_url)
        return album_cover_url
    else:
        return "https://i.postimg.cc/0QNxYz4V/social.png"
def recommend(song):
    index = music[music['title'] == song].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_music_names = []
    recommended_music_posters = []
    for i in distances[1:6]:
        # fetch the movie poster
        artist = music.iloc[i[0]].artists[0:12]
        print("artist name ",artist)
        print(music.iloc[i[0]].title)
        recommended_music_posters.append(get_song_album_cover_url(music.iloc[i[0]].title,artist))
        recommended_music_names.append(music.iloc[i[0]].title)

    return recommended_music_names,recommended_music_posters

# %%
recommend('Aankh Marey')
# Out:
# artist name  Mika Singh
# Hawa Hawa
# https://i.scdn.co/image/ab67616d0000b2738dfb436a57e6238c8aa21d56
# artist name  Neha Kakkar
# Gali Gali
# https://i.scdn.co/image/ab67616d0000b2736e7b5231a4e16b8013f49e1a
# artist name  Mika Singh
# Milegi Milegi
# https://i.scdn.co/image/ab67616d0000b2736d3eb740a87b5c21d2ac345f
# artist name  Mika Singh
# Sexy Baliye
# https://i.scdn.co/image/ab67616d0000b273ae79234525e2d33ed3eff5d1
# artist name  Neha Kakkar
# Do Peg Maar
# https://i.scdn.co/image/ab67616d0000b27366b66a7796c59db59ebb076b
# (['Hawa Hawa', 'Gali Gali', 'Milegi Milegi', 'Sexy Baliye', 'Do Peg Maar'],
#  ['https://i.scdn.co/image/ab67616d0000b2738dfb436a57e6238c8aa21d56',
#   'https://i.scdn.co/image/ab67616d0000b2736e7b5231a4e16b8013f49e1a',
#   'https://i.scdn.co/image/ab67616d0000b2736d3eb740a87b5c21d2ac345f',
#   'https://i.scdn.co/image/ab67616d0000b273ae79234525e2d33ed3eff5d1',
#   'https://i.scdn.co/image/ab67616d0000b27366b66a7796c59db59ebb076b'])

# %%
new_data[new_data['title']=='Mummy Aur Daddy Mein Ladai Ho Gayi']
# Out:
#                                    title  \
# 2326  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                 tags      artists
# 2326  asha bhosle bollywooddance sholaaurshabnam 6.6  Asha Bhosle

# %%
new_data
# Out:
#                                    title  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2322              Jana Tumhare Pyar Mein
# 2323             Tum Jaise Bigde Babu Se
# 2324              O Yaad Nahi Bhool Gaya
# 2325   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2326  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags  \
# 0     kumar sanu  mika singh  neha kakkar bollywoodd...
# 1     neha kakkar  tony kakkar bollywooddanceromanti...
# 2             ranveer singh bollywooddance gullyboy 9.7
# 3     jyotica tangri  shaan  subhro ganguly bollywoo...
# 4     asees kaur  rahat fateh ali khan  tanishk bagc...
# ...                                                 ...
# 2322                  mukesh bollywooddance sasural 6.2
# ...

# %% [markdown]
# ## Fetch all info of the enter song

# %%
import requests
import base64

# Function to fetch track information from Spotify API
def fetch_track_info(track_name):
    # Your Spotify API endpoint
    url = "https://api.spotify.com/v1/search"
    
    # Parameters for the query
    params = {
        "q": f"track:{track_name}",
        "type": "track"
    }
    
    # Spotify API credentials
    client_id = "70a9fb89662f4dac8d07321b259eaad7"
    client_secret = "4d6710460d764fbbb8d8753dc094d131"
    
    # Encode client ID and client secret
    client_credentials = f"{client_id}:{client_secret}"
    encoded_client_credentials = base64.b64encode(client_credentials.encode()).decode()
    
    # Headers for the request
    headers = {
        "Authorization": f"Basic {encoded_client_credentials}"
    }
    
    token_url = "https://accounts.spotify.com/api/token"
    token_params = {
        "grant_type": "client_credentials"
    }
    token_response = requests.post(token_url, data=token_params, headers=headers)
    
    if token_response.status_code == 200:
        access_token = token_response.json()["access_token"]
        
        headers["Authorization"] = f"Bearer {access_token}"
        
        response = requests.get(url, params=params, headers=headers)
        
        if response.status_code == 200:
            data = response.json()
            
            if "tracks" in data and "items" in data["tracks"] and len(data["tracks"]["items"]) > 0:
                track = data["tracks"]["items"][0]  # Assuming we want details about the first track
                track_name = track["name"]
                artist_name = track["artists"][0]["name"]
                album_name = track["album"]["name"]
                release_date = track["album"]["release_date"]
                popularity = track["popularity"]
                preview_url = track["preview_url"]
                
                
                return track_name,artist_name,album_name,release_date,popularity,preview_url
            else:
                return "None"
        else:
            return "None"
    else:
        return "None"

# Example usage
fetch_track_info("Gali Gali")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\shekh\OneDrive\Desktop\SongRecommendationSystem\songs\lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\shekh\OneDrive\Desktop\SongRecommendationSystem\songs\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...

# %%
list(new_data['title'].str.capitalize())
# Out:
# ['Aankh marey',
#  'Coca cola',
#  'Apna time aayega',
#  'Mungda',
#  'Tere bin',
#  'Gali gali',
#  'Chamma chamma',
#  'Mere gully mein',
#  'Kamariya',
#  'Ek ladki ko dekha toh aisa laga',
#  'Swag se swagat',
#  'Poster lagwa do',
#  'Daaru wargi',
#  'Dilbar',
#  'Proper patola',
#  'Doori',
#  'Dil diyan gallan',
#  'Husn parcham',
#  'Bom diggy diggy',
#  'Issaqbaazi',
#  'Mere naam tu',
#  'High rated gabru – nawabzaade',
#  'Dekhte dekhte',
#  'Zingaat',
#  'Tareefan',
#  'Mile ho tum (reprise)',
#  'Dil chori',
#  'Tere naal nachna',
#  'Dil meri na sune',
#  'Dhadak title track',
#  'Heeriye',
#  'Chogada',
#  'Gud naal ishq mitha',
#  'Paniyon sa',
#  'Milegi milegi',
#  'Morni banke',
#  'Bhare bazaar',
#  'Khalibali',
#  'Aao kabhi haveli pe',
#  'Badri ki dulhania',
#  'Cheez badi',
#  'Dholida',
#  'Sweetheart',
#  'Namo namo',
#  'Qaafirana',
#  'Tu hi re',
#  'Chhote chhote peg',
#  'Galti se mistake',
#  'Phir mulaaqat',
#  'Kala chashma',
#  'Mantoiyat',
# ...
